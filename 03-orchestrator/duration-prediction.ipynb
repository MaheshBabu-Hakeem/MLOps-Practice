# %%
# !python -V
# Out:
# Python 3.9.25

# %%
pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (3.1.4)
# Requirement already satisfied: mlflow-skinny==3.1.4 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (3.1.4)
# Requirement already satisfied: Flask<4 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (1.14.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: matplotlib<4 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (3.9.4)
# Requirement already satisfied: numpy<3 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (20.0.0)
# Requirement already satisfied: scikit-learn<2 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow) (1.4.54)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.97.0)
# Requirement already satisfied: fastapi<1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.128.8)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (3.1.41)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (1.40.0)
# Requirement already satisfied: packaging<26 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (6.33.5)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (2.9.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (2.31.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (0.39.0)
# Requirement already satisfied: Mako in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: google-auth~=2.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (2.49.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from docker<8,>=4.0.0->mlflow) (2.6.3)
# Requirement already satisfied: starlette<1.0.0,>=0.40.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from fastapi<1->mlflow-skinny==3.1.4->mlflow) (0.49.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from fastapi<1->mlflow-skinny==3.1.4->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from fastapi<1->mlflow-skinny==3.1.4->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.1.4->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.1.4->mlflow) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (42.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from graphene<4->mlflow) (3.2.8)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: zipp>=3.20 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.4->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from matplotlib<4->mlflow) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.4.7)
# Requirement already satisfied: pillow>=8 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from matplotlib<4->mlflow) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from matplotlib<4->mlflow) (6.5.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.1.4->mlflow) (0.61b0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from pandas<3->mlflow) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from pandas<3->mlflow) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.4->mlflow) (2.23.4)
# Requirement already satisfied: six>=1.5 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.4->mlflow) (2026.2.25)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.5)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from starlette<1.0.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (4.12.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<1.0.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from uvicorn<1->mlflow-skinny==3.1.4->mlflow) (0.16.0)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (2.0.0)
# Requirement already satisfied: pycparser in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.4->mlflow) (2.23)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !mlflow --version
# Out:
# mlflow, version 3.1.4

# %%
import pandas as pd

# %%
import pickle

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import root_mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("yellow-trip-data")
# Out:
# <Experiment: artifact_location='/workspaces/MLOps-Practice/mlruns/3', creation_time=1773060643172, experiment_id='3', last_update_time=1773060643172, lifecycle_stage='active', name='yellow-trip-data', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)
    print(f"Q3 Initial data Load: {len(df)} records")
    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df.duration = df.duration.dt.total_seconds() / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet')
print(f"Q4: The size of the result: {len(df_train)} records")
# Out:
# Q3 Initial data Load: 3403766 records
# Q4: The size of the result: 3316216 records

# %%
from sklearn.linear_model import LinearRegression

import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import os

with mlflow.start_run():
    train_dicts = df_train[['PULocationID', 'DOLocationID']].to_dict(orient='records')
    dv = DictVectorizer()
    X_train = dv.fit_transform(train_dicts)
    y_train = df_train['duration'].values
    
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    
    mlflow.sklearn.log_model(lr, artifact_path="model")
    print(f'Q5 Model intercept: {lr.intercept_}')
    mlflow_dir = mlflow.get_artifact_uri()
    # mlmodel_path = os.path.join(mlflow_dir.replace('file://', ''), 'model', 'MLmodel')
    
    # if os.path.exists(mlmodel_path):
    #     model_size = os.path.getsize(mlmodel_path)
    #     print(f"Q6 MLModel file path: {mlmodel_path}")
    #     print(f"Q6 MLModel file size: {model_size} bytes ({model_size / 1024:.2f} KB)")
    # else:
    #     print(f"Q6 MLModel file not found at {mlmodel_path}")
# Out:
# 2026/03/12 12:08:37 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/03/12 12:08:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Q5 Model intercept: 24.77203445209766
# 🏃 View run adorable-bear-477 at: http://localhost:5000/#/experiments/3/runs/f4f7f9223507446285327e869d968c93
# 🧪 View experiment at: http://localhost:5000/#/experiments/3

# %%
pip install xgboost
# Out:
# 3134.21s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting xgboost
#   Using cached xgboost-2.1.4-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from xgboost) (2.0.2)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Using cached nvidia_nccl_cu12-2.29.7-py3-none-manylinux_2_18_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: scipy in /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages (from xgboost) (1.13.1)
# Using cached xgboost-2.1.4-py3-none-manylinux_2_28_x86_64.whl (223.6 MB)
# Using cached nvidia_nccl_cu12-2.29.7-py3-none-manylinux_2_18_x86_64.whl (293.6 MB)
# Installing collected packages: nvidia-nccl-cu12, xgboost
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [xgboost]m1/2 [xgboost]
# Successfully installed nvidia-nccl-cu12-2.29.7 xgboost-2.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# %%
from pathlib import Path
models_folder = Path('models')
models_folder.mkdir(exist_ok=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=30,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [10:48:28] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.44482
# [1]	validation-rmse:10.77202
# [2]	validation-rmse:10.18363
# [3]	validation-rmse:9.67396
# [4]	validation-rmse:9.23166
# [5]	validation-rmse:8.84808
# [6]	validation-rmse:8.51883
# [7]	validation-rmse:8.23597
# [8]	validation-rmse:7.99320
# [9]	validation-rmse:7.78709
# [10]	validation-rmse:7.61022
# [11]	validation-rmse:7.45952
# [12]	validation-rmse:7.33049
# [13]	validation-rmse:7.22098
# [14]	validation-rmse:7.12713
# [15]	validation-rmse:7.04752
# [16]	validation-rmse:6.98005
# [17]	validation-rmse:6.92232
# [18]	validation-rmse:6.87112
# [19]	validation-rmse:6.82740
# [20]	validation-rmse:6.78995
# [21]	validation-rmse:6.75792
# [22]	validation-rmse:6.72994
# [23]	validation-rmse:6.70547
# [24]	validation-rmse:6.68390
# [25]	validation-rmse:6.66421
# [26]	validation-rmse:6.64806
# [27]	validation-rmse:6.63280
# [28]	validation-rmse:6.61924
# [29]	validation-rmse:6.60773
# 2026/03/09 10:49:06 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [10:49:07] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2026/03/09 10:51:11 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpt376ncj5/model, flavor: xgboost). Fall back to return ['xgboost==2.1.4']. Set logging level to DEBUG to see the full traceback.
# 2026/03/09 10:51:11 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run lyrical-ram-516 at: http://localhost:5000/#/experiments/1/runs/33e64b5f653945e9905b7302fb19b9fd
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
import pandas as pd

results = pd.DataFrame({
    'actual_duration': y_val,
    'predicted_duration': y_pred
})
print(results.head(10))
results['difference'] = results['actual_duration'] - results['predicted_duration']
print("Average difference:", results['difference'].mean())

results.to_csv("models/predictions_vs_actuals.csv", index=False)
mlflow.log_artifact("models/predictions_vs_actuals.csv", artifact_path="predictions")
# Out:
#    actual_duration  predicted_duration
# 0        17.916667           16.125685
# 1         6.500000            7.607263
# 2        15.250000           19.447042
# 3        18.233333           24.010212
# 4         8.966667           10.241908
# 5         7.850000           17.095030
# 6         9.700000           14.144274
# 7        11.283333            9.423327
# 8         8.733333            9.298021
# 9         1.716667           19.088913
# Average difference: 1.2705986995605845

# %%
import pandas as pd
import pickle
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
import xgboost as xgb
import mlflow
from pathlib import Path


df = pd.read_csv("/workspaces/MLOps-Practice/03-orchestrator/delhivery_data.csv") 
print(df.head())

df = df.drop(columns=['data', 'trip_creation_time', 'route_schedule_uuid', 'trip_uuid', 'cutoff_timestamp'], errors='ignore')

target = 'actual_time'

categorical = [
    'source_name',
    'destination_name',
    'route_type',
    'is_cutoff'
]

numerical = [
    'actual_distance_to_destination',
    'osrm_time',
    'osrm_distance',
    'factor',
    'segment_osrm_time',
    'segment_osrm_distance',
    'segment_factor'
]
df = df.dropna(subset=[target])
df_train, df_val = train_test_split(df, test_size=0.2, random_state=42)

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

y_train = df_train[target].values
y_val = df_val[target].values

mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("delhivery-duration-experiment")

models_folder = Path('models')
models_folder.mkdir(exist_ok=True)

with mlflow.start_run(nested=True):
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    params = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'learning_rate': 0.1,
        'max_depth': 6,
        'min_child_weight': 1,
        'seed': 42
    }

    mlflow.log_params(params)

    booster = xgb.train(
        params=params,
        dtrain=train,
        num_boost_round=100,
        evals=[(valid, 'validation')],
        early_stopping_rounds=10
    )


    y_pred = booster.predict(valid)

    rmse = root_mean_squared_error(y_val, y_pred)

    print(f"RMSE: {rmse:.3f}")

    mlflow.log_metric("rmse", rmse)
    with open("models/preprocessor_delhivery.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor_delhivery.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="model")
    results = pd.DataFrame({
        "actual_duration": y_val,
        "predicted_duration": y_pred
    })
    results.to_csv("models/delhivery_predictions.csv", index=False)
    mlflow.log_artifact("models/delhivery_predictions.csv", artifact_path="predictions")
# Out:
#        data          trip_creation_time  \
# 0  training  2018-09-20 02:35:36.476840
# 1  training  2018-09-20 02:35:36.476840
# 2  training  2018-09-20 02:35:36.476840
# 3  training  2018-09-20 02:35:36.476840
# 4  training  2018-09-20 02:35:36.476840
#
#                                  route_schedule_uuid route_type  \
# 0  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 1  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 2  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 3  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 4  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
#
#                  trip_uuid source_center                 source_name  \
# 0  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 1  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 2  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 3  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 4  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
#
#   destination_center               destination_name  \
# 0       IND388620AAB  Khambhat_MotvdDPP_D (Gujarat)
# 1       IND388620AAB  Khambhat_MotvdDPP_D (Gujarat)
# 2       IND388620AAB  Khambhat_MotvdDPP_D (Gujarat)
# 3       IND388620AAB  Khambhat_MotvdDPP_D (Gujarat)
# 4       IND388620AAB  Khambhat_MotvdDPP_D (Gujarat)
#
#                 od_start_time  ...            cutoff_timestamp  \
# 0  2018-09-20 03:21:32.418600  ...         2018-09-20 04:27:55
# 1  2018-09-20 03:21:32.418600  ...         2018-09-20 04:17:55
# 2  2018-09-20 03:21:32.418600  ...  2018-09-20 04:01:19.505586
# 3  2018-09-20 03:21:32.418600  ...         2018-09-20 03:39:57
# 4  2018-09-20 03:21:32.418600  ...         2018-09-20 03:33:55
#
#    actual_distance_to_destination  actual_time  osrm_time osrm_distance  \
# 0                       10.435660         14.0       11.0       11.9653
# 1                       18.936842         24.0       20.0       21.7243
# 2                       27.637279         40.0       28.0       32.5395
# 3                       36.118028         62.0       40.0       45.5620
# 4                       39.386040         68.0       44.0       54.2181
#
#      factor  segment_actual_time  segment_osrm_time  segment_osrm_distance  \
# 0  1.272727                 14.0               11.0                11.9653
# 1  1.200000                 10.0                9.0                 9.7590
# 2  1.428571                 16.0                7.0                10.8152
# 3  1.550000                 21.0               12.0                13.0224
# 4  1.545455                  6.0                5.0                 3.9153
#
#    segment_factor
# 0        1.272727
# 1        1.111111
# 2        2.285714
# 3        1.750000
# 4        1.200000
#
# [5 rows x 24 columns]
# [0]	validation-rmse:539.48926
# [1]	validation-rmse:486.27303
# [2]	validation-rmse:438.52949
# [3]	validation-rmse:395.56884
# [4]	validation-rmse:356.87901
# [5]	validation-rmse:321.95071
# [6]	validation-rmse:290.58722
# [7]	validation-rmse:262.33153
# [8]	validation-rmse:236.81886
# [9]	validation-rmse:213.98505
# [10]	validation-rmse:193.30926
# [11]	validation-rmse:174.78856
# [12]	validation-rmse:158.08293
# [13]	validation-rmse:143.06514
# [14]	validation-rmse:129.54643
# [15]	validation-rmse:117.40477
# [16]	validation-rmse:106.47050
# [17]	validation-rmse:96.65722
# [18]	validation-rmse:87.89909
# [19]	validation-rmse:80.01022
# [20]	validation-rmse:72.95315
# [21]	validation-rmse:66.68623
# [22]	validation-rmse:61.07896
# [23]	validation-rmse:56.03590
# [24]	validation-rmse:51.59117
# [25]	validation-rmse:47.68410
# [26]	validation-rmse:44.16707
# [27]	validation-rmse:41.09498
# [28]	validation-rmse:38.37053
# [29]	validation-rmse:35.99390
# [30]	validation-rmse:33.94487
# [31]	validation-rmse:32.10847
# [32]	validation-rmse:30.52589
# [33]	validation-rmse:29.12971
# [34]	validation-rmse:27.92937
# [35]	validation-rmse:26.89574
# [36]	validation-rmse:26.04648
# [37]	validation-rmse:25.23515
# [38]	validation-rmse:24.58364
# [39]	validation-rmse:23.98466
# [40]	validation-rmse:23.48416
# [41]	validation-rmse:23.04979
# [42]	validation-rmse:22.69251
# [43]	validation-rmse:22.42463
# [44]	validation-rmse:22.12356
# [45]	validation-rmse:21.90973
# [46]	validation-rmse:21.66238
# [47]	validation-rmse:21.45230
# [48]	validation-rmse:21.26219
# [49]	validation-rmse:21.12029
# [50]	validation-rmse:20.99276
# [51]	validation-rmse:20.84250
# [52]	validation-rmse:20.73035
# [53]	validation-rmse:20.65248
# [54]	validation-rmse:20.55884
# [55]	validation-rmse:20.46422
# [56]	validation-rmse:20.39790
# [57]	validation-rmse:20.35790
# [58]	validation-rmse:20.31018
# [59]	validation-rmse:20.25888
# [60]	validation-rmse:20.21933
# [61]	validation-rmse:20.16533
# [62]	validation-rmse:20.12734
# [63]	validation-rmse:20.05720
# [64]	validation-rmse:19.99294
# [65]	validation-rmse:19.91166
# [66]	validation-rmse:19.87958
# [67]	validation-rmse:19.83941
# [68]	validation-rmse:19.76252
# [69]	validation-rmse:19.73906
# [70]	validation-rmse:19.70154
# [71]	validation-rmse:19.67312
# [72]	validation-rmse:19.66073
# [73]	validation-rmse:19.61951
# [74]	validation-rmse:19.61381
# [75]	validation-rmse:19.55735
# [76]	validation-rmse:19.53181
# [77]	validation-rmse:19.52839
# [78]	validation-rmse:19.52441
# [79]	validation-rmse:19.51545
# [80]	validation-rmse:19.49966
# [81]	validation-rmse:19.43944
# [82]	validation-rmse:19.42926
# [83]	validation-rmse:19.42166
# [84]	validation-rmse:19.39919
# [85]	validation-rmse:19.39404
# [86]	validation-rmse:19.34888
# [87]	validation-rmse:19.33490
# [88]	validation-rmse:19.32540
# [89]	validation-rmse:19.31906
# [90]	validation-rmse:19.30365
# [91]	validation-rmse:19.30072
# [92]	validation-rmse:19.28750
# [93]	validation-rmse:19.27975
# [94]	validation-rmse:19.25730
# [95]	validation-rmse:19.24951
# [96]	validation-rmse:19.20548
# [97]	validation-rmse:19.20083
# [98]	validation-rmse:19.16020
# [99]	validation-rmse:19.15957
# RMSE: 19.160
# 2026/03/09 11:24:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /home/codespace/anaconda3/envs/03-exp-orch/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [11:24:49] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2026/03/09 11:24:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run zealous-bug-17 at: http://localhost:5000/#/experiments/2/runs/76436985d4da4c538229fb4c20cb4c84
# 🧪 View experiment at: http://localhost:5000/#/experiments/2

# %%
import pandas as pd
import os
import mlflow

results = pd.DataFrame({
    'actual_duration': y_val,
    'predicted_duration': y_pred
})

results['difference'] = results['actual_duration'] - results['predicted_duration']
print(results.head(10))
print("\nAverage difference:", results['difference'].mean())

os.makedirs("models", exist_ok=True)
results.to_csv("models/predictions_vs_actuals.csv", index=False)
print("Saved results to models/predictions_vs_actuals.csv")

mlflow.log_artifact("models/predictions_vs_actuals.csv", artifact_path="predictions")
print("Logged artifact to MLflow under 'predictions/'")
# Out:
#    actual_duration  predicted_duration  difference
# 0            440.0          442.456970   -2.456970
# 1             57.0           48.008472    8.991528
# 2            238.0          241.649765   -3.649765
# 3           1724.0         1711.571899   12.428101
# 4            999.0          996.462341    2.537659
# 5            793.0          786.916626    6.083374
# 6            276.0          279.496216   -3.496216
# 7            764.0          745.722717   18.277283
# 8             65.0           67.620132   -2.620132
# 9            894.0          896.887451   -2.887451
#
# Average difference: 0.07410632733718747
# Saved results to models/predictions_vs_actuals.csv
# Logged artifact to MLflow under 'predictions/'
